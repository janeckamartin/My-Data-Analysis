# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
import zipfile
with zipfile.ZipFile("london.zip","r") as zip_ref:
    zip_ref.extractall("london")

# %%
london_excl_mhw = gpd.read_file('/content/london/london/London_Borough_Excluding_MHW.shp')
london_ward = gpd.read_file('/content/london/london/London_Ward_CityMerged.shp')


london_ward.plot().axis('off')
# Out:
# (500648.735, 564876.965, 153596.645, 203188.055)
