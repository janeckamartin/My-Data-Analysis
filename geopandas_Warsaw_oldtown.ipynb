# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
old_town_warsaw = gpd.read_file('old_town.geojson')
fig, ax = plt.subplots(figsize=(16, 12))

old_town_warsaw.plot(ax=ax, cmap='BuPu')

plt.axis('off')
# Out:
# (21.00005056, 21.02094924, 52.24660002, 52.255399579999995)

# %%
old_town_warsaw.head()
# Out:
#    CEMT access access:conditional addr:city addr:city:simc addr:country  \
# 0  None   None               None      None           None         None
# 1  None   None               None      None           None         None
# 2  None   None               None      None           None         None
# 3  None   None               None      None           None         None
# 4  None   None               None      None           None         None
#
#   addr:housename addr:housenumber addr:postcode addr:street  ... waterway  \
# 0           None             None          None        None  ...     None
# 1           None             None          None        None  ...     None
# 2           None             None          None        None  ...     None
# 3           None             None          None        None  ...     None
# 4           None             None          None        None  ...     None
#
#   website whc:criteria whc:inscription_date wheelchair width wikidata  \
# 0    None         None                 None       None  None     None
# 1    None         None                 None       None  None     None
# 2    None         None                 None       None  None     None
# 3    None         None                 None       None  None     None
# 4    None         None                 None       None  None     None
#
#   wikimedia_commons wikipedia                   geometry
# 0              None      None  POINT (21.00329 52.25497)
# 1              None      None  POINT (21.01824 52.24859)
# 2              None      None   POINT (21.0182 52.24862)
# 3              None      None   POINT (21.0187 52.24849)
# 4              None      None  POINT (21.01668 52.24725)
#
# [5 rows x 334 columns]

# %%
old_town_warsaw.plot()
# Out:
# <Axes: >

# %%
old_town_warsaw.plot(cmap='YlGn_r')

# from matplotlib import colormaps
# list(colormaps)
# Out:
# <Axes: >
