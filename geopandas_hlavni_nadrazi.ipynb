# %%
import zipfile
with zipfile.ZipFile("hlavni_nadrazi.zip","r") as zip_ref:
    zip_ref.extractall("hlavni_nadrazi")

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
polygons = gpd.read_file("/content/hlavni_nadrazi/Hlavní_nádraží_poly.shp")

# %%
polygons.plot()
plt.axis('off')
plt.figure(figsize=(16,12))
plt.show()
