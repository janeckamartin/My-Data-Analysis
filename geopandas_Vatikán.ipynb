# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
vatican = gpd.read_file('vatican.geojson')

fig, ax = plt.subplots(figsize=(16, 12))

vatican.plot(ax=ax, cmap='BuPu')

plt.axis('off')
plt.show()
