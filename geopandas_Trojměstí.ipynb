# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
import zipfile
with zipfile.ZipFile("Tricity_shp.zip","r") as zip_ref:
    zip_ref.extractall(".")

# %%
lines = gpd.read_file("Trojmiasto_shp/Trojmiasto_planet_osm_line_lines.shp")

fig, ax = plt.subplots(figsize=(10, 20))
lines.plot(ax=ax)

plt.axis('off')

plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# <ipython-input-16-b496d338b9aa> in <cell line: 0>()
# ----> 1 polygons = gpd.read_file("/content/testx/test_poly.shp")
#       2 polygons = polygons[polygons["building"].isin(['train_station', 'apartments'])]
#       3
#       4 lines = gpd.read_file("/content/testx/test_line.shp")
#       5 lines = lines[lines["osm_type"] == "ways_line"]
#
# /usr/local/lib/python3.11/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     292
#     293     if engine == "pyogrio":
# --> 294         return _read_file_pyogrio(
#     295             filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     296         )
#
# /usr/local/lib/python3.11/dist-packages/geopandas/io/file.py in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
# ...
